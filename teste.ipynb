# %%
import pandas as pd 
import numpy as np 

a = pd.read_csv("Cenario4_Sensores_300_Registros_novos.csv", sep=";")
# aa = a[["Equipamento"] == "Torno-CNC"].count()
print(a[a['Equipamento'] == 'Torno-CNC']["Equipamento"].count())
# Out:
# 10
